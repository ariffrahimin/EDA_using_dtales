# %%
import pandas as pd
import dtale as dt

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/US-shooting-incidents.csv')
df
# Out:
#       Unnamed: 0                                     person  \
# 0              1                                  K9 Roscoe
# 1              2            Police Officer Roy L. Leon, Jr.
# 2              3                  Officer Stanley D. Pounds
# 3              4  Enforcement Agent Ernest Joseph Gray, Jr.
# 4              5       Police Officer James W. Carozza, Jr.
# ...          ...                                        ...
# 4994        4995   Deputy Sheriff David Francis Michel, Jr.
# 4995        4996                                   K9 Tyson
# 4996        4997                                   K9 Credo
# 4997        4998    Deputy Sheriff Martin Tase Sturgill, II
# 4998        4999                                  K9 Roscoe
#
#                                             dept  \
# 0                  Phoenix Police Department, AZ
# 1             Cotton Plant Police Department, AR
# 2                     Portland Police Bureau, OR
# ...

# %%
df=df.iloc[: , 1:]
df
# Out:
#                                          person  \
# 0                                     K9 Roscoe
# 1               Police Officer Roy L. Leon, Jr.
# 2                     Officer Stanley D. Pounds
# 3     Enforcement Agent Ernest Joseph Gray, Jr.
# 4          Police Officer James W. Carozza, Jr.
# ...                                         ...
# 4994   Deputy Sheriff David Francis Michel, Jr.
# 4995                                   K9 Tyson
# 4996                                   K9 Credo
# 4997    Deputy Sheriff Martin Tase Sturgill, II
# 4998                                  K9 Roscoe
#
#                                             dept  \
# 0                  Phoenix Police Department, AZ
# 1             Cotton Plant Police Department, AR
# 2                     Portland Police Bureau, OR
# 3     Pennsylvania Public Utility Commission, PA
# 4               Greenburgh Police Department, NY
# ...                                          ...
# ...

# %%
dt.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://ariffs-MacBook-Air.local:40000/dtale/iframe/10"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/flask/app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/flask/app.py", line 1519, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/flask/app.py", line 1517, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/flask/app.py", line 1503, in dispatch_request
# ...
